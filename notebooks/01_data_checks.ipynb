# %%
from pathlib import Path
import sys

# add the project root (parent of 'notebooks') to Python's import path
PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

PROJECT_ROOT
# Out:
# WindowsPath('C:/Users/crowe/OneDrive - University College Dublin/Masters/FIN42020 - Derivative Securities/Project/FIN42020-Derivative-Securities-Project')

# %%
from src.data_loader import (
    load_calls, load_puts, load_price,
    load_usgg1m, load_atm_series,
    TRADE_DATE, EXPIRY_DATE,
)

calls = load_calls()
puts = load_puts()
price = load_price()
usgg = load_usgg1m()
atm = load_atm_series()

calls.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 11
#       9 price = load_price()
#      10 usgg = load_usgg1m()
# ---> 11 atm = load_atm_series()
#      13 calls.head()
#
# File ~\OneDrive - University College Dublin\Masters\FIN42020 - Derivative Securities\Project\FIN42020-Derivative-Securities-Project\src\data_loader.py:83, in load_atm_series()
#      81 # ensure the crucial columns exist
#      82 if "Date" not in df.columns:
# ---> 83     raise ValueError("ATM sheet has no 'Date' column")
#      84 if "Last Price" not in df.columns:
#      85     raise ValueError("ATM sheet has no 'Last Price' column")
#
# ValueError: ATM sheet has no 'Date' column
